# %%
# !apt-get install libeccodes-tools
# !pip install pdbufr
# !pip install cartopy
# !pip install pybufrkit

# %%
import pdbufr
df_0030 = pdbufr.read_bufr('drive/MyDrive/2024-02-14/00-30/AMV.bufr', columns="data",flat=True)
df = df_0030
# print(df)
df.T[0:40]
# Out:
# /usr/local/lib/python3.10/dist-packages/gribapi/__init__.py:23: UserWarning: ecCodes 2.31.0 or higher is recommended. You are running version 2.24.2
#   warnings.warn(
#                                                           0      \
# #1#centre                                                   254
# #1#subCentre                                                  0
# #1#softwareVersionNumber                               MPEF_2.9
# #1#databaseIdentification                                  None
# #1#satelliteIdentifier                                       56
# #1#satelliteChannelCentreFrequency             47966800000000.0
# #1#directionOfMotionOfMovingObservingPlatform              None
# #1#crossTrackResolution                                    None
# #1#alongTrackResolution                                    None
# #1#segmentSizeAtNadirInXDirection                         72000
# #1#segmentSizeAtNadirInYDirection                         72000
# #1#windProcessingMethod                                    None
# #1#tracerCorrelationMethod                                    2
# #1#satelliteDerivedWindComputationMethod                      3
# #1#landOrSeaQualifier                                         0
# #1#dayOrNightQualifier                                     None
# #1#gridPointIdentifier                                     None
# #1#latitude                                            23.82842
# #1#longitude                                           -9.49116
# #1#year                                                    2024
# #1#month                                                      2
# #1#day                                                       14
# #1#hour                                                       0
# #1#minute                                                    30
# #1#second                                                     0
# #1#timePeriod                                              3600
# #1#extendedHeightAssignmentMethod                             4
# #1#pressure                                             20700.0
# #1#windDirection                                            227
# #1#windSpeed                                               19.0
# #1#u                                                       13.9
# #1#v                                                       12.9
# #1#airTemperature                                         220.4
# #1#heightOfTopOfCloud                                      None
# #1#satelliteZenithAngle                                   64.82
# #1#observationSequenceNumber                               None
# #2#extendedHeightAssignmentMethod                             2
# #2#pressure                                             22080.0
# #2#airTemperature                                         223.2
# #2#heightOfTopOfCloud                                      None
#
#                                                           1      \
# #1#centre                                                   254
# #1#subCentre                                                  0
# #1#softwareVersionNumber                               MPEF_2.9
# #1#databaseIdentification                                  None
# #1#satelliteIdentifier                                       56
# #1#satelliteChannelCentreFrequency             47966800000000.0
# #1#directionOfMotionOfMovingObservingPlatform              None
# #1#crossTrackResolution                                    None
# #1#alongTrackResolution                                    None
# #1#segmentSizeAtNadirInXDirection                         72000
# #1#segmentSizeAtNadirInYDirection                         72000
# #1#windProcessingMethod                                    None
# #1#tracerCorrelationMethod                                    2
# #1#satelliteDerivedWindComputationMethod                      3
# #1#landOrSeaQualifier                                         0
# #1#dayOrNightQualifier                                     None
# #1#gridPointIdentifier                                     None
# #1#latitude                                             23.5862
# #1#longitude                                          -11.03896
# #1#year                                                    2024
# #1#month                                                      2
# #1#day                                                       14
# #1#hour                                                       0
# #1#minute                                                    30
# #1#second                                                     0
# #1#timePeriod                                              3600
# #1#extendedHeightAssignmentMethod                             4
# #1#pressure                                             36940.0
# #1#windDirection                                            224
# #1#windSpeed                                               20.5
# #1#u                                                       14.2
# #1#v                                                       14.8
# #1#airTemperature                                         249.3
# #1#heightOfTopOfCloud                                      None
# #1#satelliteZenithAngle                                   66.25
# #1#observationSequenceNumber                               None
# #2#extendedHeightAssignmentMethod                             2
# #2#pressure                                             23760.0
# #2#airTemperature                                         227.0
# #2#heightOfTopOfCloud                                      None
#
#                                                           2      \
# #1#centre                                                   254
# #1#subCentre                                                  0
# #1#softwareVersionNumber                               MPEF_2.9
# #1#databaseIdentification                                  None
# #1#satelliteIdentifier                                       56
# #1#satelliteChannelCentreFrequency             47966800000000.0
# #1#directionOfMotionOfMovingObservingPlatform              None
# #1#crossTrackResolution                                    None
# #1#alongTrackResolution                                    None
# #1#segmentSizeAtNadirInXDirection                         72000
# #1#segmentSizeAtNadirInYDirection                         72000
# #1#windProcessingMethod                                    None
# #1#tracerCorrelationMethod                                    2
# #1#satelliteDerivedWindComputationMethod                      3
# #1#landOrSeaQualifier                                         0
# #1#dayOrNightQualifier                                     None
# #1#gridPointIdentifier                                     None
# #1#latitude                                            24.17961
# #1#longitude                                          -10.11116
# #1#year                                                    2024
# #1#month                                                      2
# #1#day                                                       14
# #1#hour                                                       0
# #1#minute                                                    30
# #1#second                                                     0
# #1#timePeriod                                              3600
# #1#extendedHeightAssignmentMethod                             4
# #1#pressure                                             20680.0
# #1#windDirection                                            227
# #1#windSpeed                                               20.5
# #1#u                                                       15.0
# #1#v                                                       14.0
# #1#airTemperature                                         220.3
# #1#heightOfTopOfCloud                                      None
# #1#satelliteZenithAngle                                   65.49
# #1#observationSequenceNumber                               None
# #2#extendedHeightAssignmentMethod                             2
# #2#pressure                                             21560.0
# #2#airTemperature                                         221.9
# #2#heightOfTopOfCloud                                      None
#
#                                                           3      \
# #1#centre                                                   254
# #1#subCentre                                                  0
# #1#softwareVersionNumber                               MPEF_2.9
# #1#databaseIdentification                                  None
# #1#satelliteIdentifier                                       56
# #1#satelliteChannelCentreFrequency             47966800000000.0
# #1#directionOfMotionOfMovingObservingPlatform              None
# #1#crossTrackResolution                                    None
# #1#alongTrackResolution                                    None
# #1#segmentSizeAtNadirInXDirection                         72000
# #1#segmentSizeAtNadirInYDirection                         72000
# #1#windProcessingMethod                                    None
# #1#tracerCorrelationMethod                                    1
# #1#satelliteDerivedWindComputationMethod                      5
# #1#landOrSeaQualifier                                         0
# #1#dayOrNightQualifier                                     None
# #1#gridPointIdentifier                                     None
# #1#latitude                                            24.08278
# #1#longitude                                           -4.23806
# #1#year                                                    2024
# #1#month                                                      2
# #1#day                                                       14
# #1#hour                                                       0
# #1#minute                                                    30
# #1#second                                                     0
# #1#timePeriod                                              3600
# #1#extendedHeightAssignmentMethod                            10
# #1#pressure                                             30770.0
# #1#windDirection                                            190
# #1#windSpeed                                                9.8
# #1#u                                                        1.8
# #1#v                                                        9.6
# #1#airTemperature                                         237.9
# #1#heightOfTopOfCloud                                      None
# #1#satelliteZenithAngle                                   59.85
# #1#observationSequenceNumber                               None
# #2#extendedHeightAssignmentMethod                             2
# #2#pressure                                             28290.0
# #2#airTemperature                                         234.4
# #2#heightOfTopOfCloud                                      None
#
#                                                           4      \
# #1#centre                                                   254
# #1#subCentre                                                  0
# #1#softwareVersionNumber                               MPEF_2.9
# #1#databaseIdentification                                  None
# #1#satelliteIdentifier                                       56
# #1#satelliteChannelCentreFrequency             47966800000000.0
# #1#directionOfMotionOfMovingObservingPlatform              None
# #1#crossTrackResolution                                    None
# #1#alongTrackResolution                                    None
# #1#segmentSizeAtNadirInXDirection                         72000
# #1#segmentSizeAtNadirInYDirection                         72000
# #1#windProcessingMethod                                    None
# #1#tracerCorrelationMethod                                    2
# #1#satelliteDerivedWindComputationMethod                      3
# #1#landOrSeaQualifier                                         0
# #1#dayOrNightQualifier                                     None
# #1#gridPointIdentifier                                     None
# #1#latitude                                            24.51771
# #1#longitude                                          -10.12116
# #1#year                                                    2024
# #1#month                                                      2
# #1#day                                                       14
# #1#hour                                                       0
# #1#minute                                                    30
# #1#second                                                     0
# #1#timePeriod                                              3600
# #1#extendedHeightAssignmentMethod                             4
# #1#pressure                                             21120.0
# #1#windDirection                                            226
# #1#windSpeed                                               20.6
# #1#u                                                       14.7
# #1#v                                                       14.4
# #1#airTemperature                                         221.0
# #1#heightOfTopOfCloud                                      None
# #1#satelliteZenithAngle                                   65.57
# #1#observationSequenceNumber                               None
# #2#extendedHeightAssignmentMethod                             2
# #2#pressure                                             21840.0
# #2#airTemperature                                         222.5
# #2#heightOfTopOfCloud                                      None
#
#                                                           5      \
# #1#centre                                                   254
# #1#subCentre                                                  0
# #1#softwareVersionNumber                               MPEF_2.9
# #1#databaseIdentification                                  None
# #1#satelliteIdentifier                                       56
# #1#satelliteChannelCentreFrequency             47966800000000.0
# #1#directionOfMotionOfMovingObservingPlatform              None
# #1#crossTrackResolution                                    None
# #1#alongTrackResolution                                    None
# #1#segmentSizeAtNadirInXDirection                         72000
# #1#segmentSizeAtNadirInYDirection                         72000
# #1#windProcessingMethod                                    None
# #1#tracerCorrelationMethod                                    2
# #1#satelliteDerivedWindComputationMethod                      3
# #1#landOrSeaQualifier                                         0
# #1#dayOrNightQualifier                                     None
# #1#gridPointIdentifier                                     None
# #1#latitude                                            24.89483
# #1#longitude                                           -8.98093
# #1#year                                                    2024
# #1#month                                                      2
# #1#day                                                       14
# #1#hour                                                       0
# #1#minute                                                    30
# #1#second                                                     0
# #1#timePeriod                                              3600
# #1#extendedHeightAssignmentMethod                             4
# #1#pressure                                             22870.0
# #1#windDirection                                            229
# #1#windSpeed                                               20.3
# #1#u                                                       15.3
# #1#v                                                       13.4
# #1#airTemperature                                         225.3
# #1#heightOfTopOfCloud                                      None
# #1#satelliteZenithAngle                                   64.57
# #1#observationSequenceNumber                               None
# #2#extendedHeightAssignmentMethod                             2
# #2#pressure                                             23080.0
# #2#airTemperature                                         225.9
# #2#heightOfTopOfCloud                                      None
#
#                                                           6      \
# #1#centre                                                   254
# #1#subCentre                                                  0
# #1#softwareVersionNumber                               MPEF_2.9
# #1#databaseIdentification                                  None
# #1#satelliteIdentifier                                       56
# #1#satelliteChannelCentreFrequency             47966800000000.0
# #1#directionOfMotionOfMovingObservingPlatform              None
# #1#crossTrackResolution                                    None
# #1#alongTrackResolution                                    None
# #1#segmentSizeAtNadirInXDirection                         72000
# #1#segmentSizeAtNadirInYDirection                         72000
# #1#windProcessingMethod                                    None
# #1#tracerCorrelationMethod                                    1
# #1#satelliteDerivedWindComputationMethod                      5
# #1#landOrSeaQualifier                                         0
# #1#dayOrNightQualifier                                     None
# #1#gridPointIdentifier                                     None
# #1#latitude                                             24.7047
# #1#longitude                                           -2.65245
# #1#year                                                    2024
# #1#month                                                      2
# #1#day                                                       14
# #1#hour                                                       0
# #1#minute                                                    30
# #1#second                                                     0
# #1#timePeriod                                              3600
# #1#extendedHeightAssignmentMethod                            10
# #1#pressure                                             31720.0
# #1#windDirection                                            211
# #1#windSpeed                                               17.9
# #1#u                                                        9.3
# #1#v                                                       15.3
# #1#airTemperature                                         239.7
# #1#heightOfTopOfCloud                                      None
# #1#satelliteZenithAngle                                   58.51
# #1#observationSequenceNumber                               None
# #2#extendedHeightAssignmentMethod                             2
# #2#pressure                                             28530.0
# #2#airTemperature                                         234.8
# #2#heightOfTopOfCloud                                      None
#
#                                                           7      \
# #1#centre                                                   254
# #1#subCentre                                                  0
# #1#softwareVersionNumber                               MPEF_2.9
# #1#databaseIdentification                                  None
# #1#satelliteIdentifier                                       56
# #1#satelliteChannelCentreFrequency             47966800000000.0
# #1#directionOfMotionOfMovingObservingPlatform              None
# #1#crossTrackResolution                                    None
# #1#alongTrackResolution                                    None
# #1#segmentSizeAtNadirInXDirection                         72000
# #1#segmentSizeAtNadirInYDirection                         72000
# #1#windProcessingMethod                                    None
# #1#tracerCorrelationMethod                                    1
# #1#satelliteDerivedWindComputationMethod                      5
# #1#landOrSeaQualifier                                         0
# #1#dayOrNightQualifier                                     None
# #1#gridPointIdentifier                                     None
# #1#latitude                                            24.80431
# #1#longitude                                           -3.96695
# #1#year                                                    2024
# #1#month                                                      2
# #1#day                                                       14
# #1#hour                                                       0
# #1#minute                                                    30
# #1#second                                                     0
# #1#timePeriod                                              3600
# #1#extendedHeightAssignmentMethod                            10
# #1#pressure                                             32080.0
# #1#windDirection                                            222
# #1#windSpeed                                               20.0
# #1#u                                                       13.3
# #1#v                                                       14.9
# #1#airTemperature                                         239.9
# #1#heightOfTopOfCloud                                      None
# #1#satelliteZenithAngle                                   59.79
# #1#observationSequenceNumber                               None
# #2#extendedHeightAssignmentMethod                             2
# #2#pressure                                             29140.0
# #2#airTemperature                                         235.6
# #2#heightOfTopOfCloud                                      None
#
#                                                           8      \
# #1#centre                                                   254
# #1#subCentre                                                  0
# #1#softwareVersionNumber                               MPEF_2.9
# #1#databaseIdentification                                  None
# #1#satelliteIdentifier                                       56
# #1#satelliteChannelCentreFrequency             47966800000000.0
# #1#directionOfMotionOfMovingObservingPlatform              None
# #1#crossTrackResolution                                    None
# #1#alongTrackResolution                                    None
# #1#segmentSizeAtNadirInXDirection                         72000
# #1#segmentSizeAtNadirInYDirection                         72000
# #1#windProcessingMethod                                    None
# #1#tracerCorrelationMethod                                    2
# #1#satelliteDerivedWindComputationMethod                      3
# #1#landOrSeaQualifier                                         0
# #1#dayOrNightQualifier                                     None
# #1#gridPointIdentifier                                     None
# #1#latitude                                            25.32484
# #1#longitude                                           -8.67126
# #1#year                                                    2024
# #1#month                                                      2
# #1#day                                                       14
# #1#hour                                                       0
# #1#minute                                                    30
# #1#second                                                     0
# #1#timePeriod                                              3600
# #1#extendedHeightAssignmentMethod                             4
# #1#pressure                                             25630.0
# #1#windDirection                                            241
# #1#windSpeed                                               20.2
# #1#u                                                       17.6
# #1#v                                                        9.9
# #1#airTemperature                                         232.0
# #1#heightOfTopOfCloud                                      None
# #1#satelliteZenithAngle                                   64.38
# #1#observationSequenceNumber                               None
# #2#extendedHeightAssignmentMethod                             2
# #2#pressure                                             23350.0
# #2#airTemperature                                         226.6
# #2#heightOfTopOfCloud                                      None
#
#                                                           9      ...  \
# #1#centre                                                   254  ...
# #1#subCentre                                                  0  ...
# #1#softwareVersionNumber                               MPEF_2.9  ...
# #1#databaseIdentification                                  None  ...
# #1#satelliteIdentifier                                       56  ...
# #1#satelliteChannelCentreFrequency             47966800000000.0  ...
# #1#directionOfMotionOfMovingObservingPlatform              None  ...
# #1#crossTrackResolution                                    None  ...
# #1#alongTrackResolution                                    None  ...
# #1#segmentSizeAtNadirInXDirection                         72000  ...
# #1#segmentSizeAtNadirInYDirection                         72000  ...
# #1#windProcessingMethod                                    None  ...
# #1#tracerCorrelationMethod                                    2  ...
# #1#satelliteDerivedWindComputationMethod                      3  ...
# #1#landOrSeaQualifier                                         0  ...
# #1#dayOrNightQualifier                                     None  ...
# #1#gridPointIdentifier                                     None  ...
# #1#latitude                                            25.29468  ...
# #1#longitude                                          -10.71571  ...
# #1#year                                                    2024  ...
# #1#month                                                      2  ...
# #1#day                                                       14  ...
# #1#hour                                                       0  ...
# #1#minute                                                    30  ...
# #1#second                                                     0  ...
# #1#timePeriod                                              3600  ...
# #1#extendedHeightAssignmentMethod                             4  ...
# #1#pressure                                             26340.0  ...
# #1#windDirection                                            224  ...
# #1#windSpeed                                               25.2  ...
# #1#u                                                       17.6  ...
# #1#v                                                       18.1  ...
# #1#airTemperature                                         232.7  ...
# #1#heightOfTopOfCloud                                      None  ...
# #1#satelliteZenithAngle                                    66.3  ...
# #1#observationSequenceNumber                               None  ...
# #2#extendedHeightAssignmentMethod                             2  ...
# #2#pressure                                             23670.0  ...
# #2#airTemperature                                         226.6  ...
# #2#heightOfTopOfCloud                                      None  ...
#
#                                                            31337  \
# #1#centre                                                    254
# #1#subCentre                                                   0
# #1#softwareVersionNumber                                MPEF_2.9
# #1#databaseIdentification                                   None
# #1#satelliteIdentifier                                        56
# #1#satelliteChannelCentreFrequency             399723300000000.0
# #1#directionOfMotionOfMovingObservingPlatform               None
# #1#crossTrackResolution                                     None
# #1#alongTrackResolution                                     None
# #1#segmentSizeAtNadirInXDirection                          32000
# #1#segmentSizeAtNadirInYDirection                          32000
# #1#windProcessingMethod                                     None
# #1#tracerCorrelationMethod                                     2
# #1#satelliteDerivedWindComputationMethod                       2
# #1#landOrSeaQualifier                                          1
# #1#dayOrNightQualifier                                      None
# #1#gridPointIdentifier                                      None
# #1#latitude                                            -23.59451
# #1#longitude                                            88.55533
# #1#year                                                     2024
# #1#month                                                       2
# #1#day                                                        14
# #1#hour                                                        0
# #1#minute                                                     30
# #1#second                                                      0
# #1#timePeriod                                               3600
# #1#extendedHeightAssignmentMethod                              4
# #1#pressure                                              87050.0
# #1#windDirection                                             126
# #1#windSpeed                                                 3.7
# #1#u                                                        -3.0
# #1#v                                                         2.2
# #1#airTemperature                                          289.2
# #1#heightOfTopOfCloud                                       None
# #1#satelliteZenithAngle                                     57.1
# #1#observationSequenceNumber                                None
# #2#extendedHeightAssignmentMethod                              1
# #2#pressure                                              76020.0
# #2#airTemperature                                          285.1
# #2#heightOfTopOfCloud                                       None
#
#                                                            31338  \
# #1#centre                                                    254
# #1#subCentre                                                   0
# #1#softwareVersionNumber                                MPEF_2.9
# #1#databaseIdentification                                   None
# #1#satelliteIdentifier                                        56
# #1#satelliteChannelCentreFrequency             399723300000000.0
# #1#directionOfMotionOfMovingObservingPlatform               None
# #1#crossTrackResolution                                     None
# #1#alongTrackResolution                                     None
# #1#segmentSizeAtNadirInXDirection                          32000
# #1#segmentSizeAtNadirInYDirection                          32000
# #1#windProcessingMethod                                     None
# #1#tracerCorrelationMethod                                     2
# #1#satelliteDerivedWindComputationMethod                       2
# #1#landOrSeaQualifier                                          1
# #1#dayOrNightQualifier                                      None
# #1#gridPointIdentifier                                      None
# #1#latitude                                               -23.81
# #1#longitude                                            88.35706
# #1#year                                                     2024
# #1#month                                                       2
# #1#day                                                        14
# #1#hour                                                        0
# #1#minute                                                     30
# #1#second                                                      0
# #1#timePeriod                                               3600
# #1#extendedHeightAssignmentMethod                              4
# #1#pressure                                              86650.0
# #1#windDirection                                             134
# #1#windSpeed                                                 4.1
# #1#u                                                        -3.0
# #1#v                                                         2.8
# #1#airTemperature                                          288.9
# #1#heightOfTopOfCloud                                       None
# #1#satelliteZenithAngle                                    57.04
# #1#observationSequenceNumber                                None
# #2#extendedHeightAssignmentMethod                              1
# #2#pressure                                              77240.0
# #2#airTemperature                                          285.5
# #2#heightOfTopOfCloud                                       None
#
#                                                            31339  \
# #1#centre                                                    254
# #1#subCentre                                                   0
# #1#softwareVersionNumber                                MPEF_2.9
# #1#databaseIdentification                                   None
# #1#satelliteIdentifier                                        56
# #1#satelliteChannelCentreFrequency             399723300000000.0
# #1#directionOfMotionOfMovingObservingPlatform               None
# #1#crossTrackResolution                                     None
# #1#alongTrackResolution                                     None
# #1#segmentSizeAtNadirInXDirection                          32000
# #1#segmentSizeAtNadirInYDirection                          32000
# #1#windProcessingMethod                                     None
# #1#tracerCorrelationMethod                                     2
# #1#satelliteDerivedWindComputationMethod                       2
# #1#landOrSeaQualifier                                          1
# #1#dayOrNightQualifier                                      None
# #1#gridPointIdentifier                                      None
# #1#latitude                                            -23.72675
# #1#longitude                                            88.02477
# #1#year                                                     2024
# #1#month                                                       2
# #1#day                                                        14
# #1#hour                                                        0
# #1#minute                                                     30
# #1#second                                                      0
# #1#timePeriod                                               3600
# #1#extendedHeightAssignmentMethod                              4
# #1#pressure                                              86180.0
# #1#windDirection                                             117
# #1#windSpeed                                                 4.2
# #1#u                                                        -3.7
# #1#v                                                         1.9
# #1#airTemperature                                          288.8
# #1#heightOfTopOfCloud                                       None
# #1#satelliteZenithAngle                                     56.7
# #1#observationSequenceNumber                                None
# #2#extendedHeightAssignmentMethod                              1
# #2#pressure                                              75910.0
# #2#airTemperature                                          284.8
# #2#heightOfTopOfCloud                                       None
#
#                                                            31340  \
# #1#centre                                                    254
# #1#subCentre                                                   0
# #1#softwareVersionNumber                                MPEF_2.9
# #1#databaseIdentification                                   None
# #1#satelliteIdentifier                                        56
# #1#satelliteChannelCentreFrequency             399723300000000.0
# #1#directionOfMotionOfMovingObservingPlatform               None
# #1#crossTrackResolution                                     None
# #1#alongTrackResolution                                     None
# #1#segmentSizeAtNadirInXDirection                          32000
# #1#segmentSizeAtNadirInYDirection                          32000
# #1#windProcessingMethod                                     None
# #1#tracerCorrelationMethod                                     2
# #1#satelliteDerivedWindComputationMethod                       2
# #1#landOrSeaQualifier                                          1
# #1#dayOrNightQualifier                                      None
# #1#gridPointIdentifier                                      None
# #1#latitude                                            -23.60356
# #1#longitude                                            87.07605
# #1#year                                                     2024
# #1#month                                                       2
# #1#day                                                        14
# #1#hour                                                        0
# #1#minute                                                     30
# #1#second                                                      0
# #1#timePeriod                                               3600
# #1#extendedHeightAssignmentMethod                              4
# #1#pressure                                              91140.0
# #1#windDirection                                             113
# #1#windSpeed                                                 3.9
# #1#u                                                        -3.6
# #1#v                                                         1.5
# #1#airTemperature                                          291.0
# #1#heightOfTopOfCloud                                       None
# #1#satelliteZenithAngle                                     55.8
# #1#observationSequenceNumber                                None
# #2#extendedHeightAssignmentMethod                              1
# #2#pressure                                              76780.0
# #2#airTemperature                                          285.1
# #2#heightOfTopOfCloud                                       None
#
#                                                            31341  \
# #1#centre                                                    254
# #1#subCentre                                                   0
# #1#softwareVersionNumber                                MPEF_2.9
# #1#databaseIdentification                                   None
# #1#satelliteIdentifier                                        56
# #1#satelliteChannelCentreFrequency             399723300000000.0
# #1#directionOfMotionOfMovingObservingPlatform               None
# #1#crossTrackResolution                                     None
# #1#alongTrackResolution                                     None
# #1#segmentSizeAtNadirInXDirection                          32000
# #1#segmentSizeAtNadirInYDirection                          32000
# #1#windProcessingMethod                                     None
# #1#tracerCorrelationMethod                                     2
# #1#satelliteDerivedWindComputationMethod                       2
# #1#landOrSeaQualifier                                          1
# #1#dayOrNightQualifier                                      None
# #1#gridPointIdentifier                                      None
# #1#latitude                                            -23.59797
# #1#longitude                                            86.19572
# #1#year                                                     2024
# #1#month                                                       2
# #1#day                                                        14
# #1#hour                                                        0
# #1#minute                                                     30
# #1#second                                                      0
# #1#timePeriod                                               3600
# #1#extendedHeightAssignmentMethod                              4
# #1#pressure                                              86910.0
# #1#windDirection                                             104
# #1#windSpeed                                                 4.1
# #1#u                                                        -3.9
# #1#v                                                         1.0
# #1#airTemperature                                          289.1
# #1#heightOfTopOfCloud                                       None
# #1#satelliteZenithAngle                                    55.03
# #1#observationSequenceNumber                                None
# #2#extendedHeightAssignmentMethod                              1
# #2#pressure                                              78460.0
# #2#airTemperature                                          285.6
# #2#heightOfTopOfCloud                                       None
#
#                                                            31342  \
# #1#centre                                                    254
# #1#subCentre                                                   0
# #1#softwareVersionNumber                                MPEF_2.9
# #1#databaseIdentification                                   None
# #1#satelliteIdentifier                                        56
# #1#satelliteChannelCentreFrequency             399723300000000.0
# #1#directionOfMotionOfMovingObservingPlatform               None
# #1#crossTrackResolution                                     None
# #1#alongTrackResolution                                     None
# #1#segmentSizeAtNadirInXDirection                          32000
# #1#segmentSizeAtNadirInYDirection                          32000
# #1#windProcessingMethod                                     None
# #1#tracerCorrelationMethod                                     2
# #1#satelliteDerivedWindComputationMethod                       2
# #1#landOrSeaQualifier                                          1
# #1#dayOrNightQualifier                                      None
# #1#gridPointIdentifier                                      None
# #1#latitude                                            -23.58245
# #1#longitude                                            89.22738
# #1#year                                                     2024
# #1#month                                                       2
# #1#day                                                        14
# #1#hour                                                        0
# #1#minute                                                     30
# #1#second                                                      0
# #1#timePeriod                                               3600
# #1#extendedHeightAssignmentMethod                              4
# #1#pressure                                              93220.0
# #1#windDirection                                             127
# #1#windSpeed                                                 3.8
# #1#u                                                        -3.0
# #1#v                                                         2.3
# #1#airTemperature                                          291.8
# #1#heightOfTopOfCloud                                       None
# #1#satelliteZenithAngle                                    57.69
# #1#observationSequenceNumber                                None
# #2#extendedHeightAssignmentMethod                              1
# #2#pressure                                              78240.0
# #2#airTemperature                                          286.6
# #2#heightOfTopOfCloud                                       None
#
#                                                            31343  \
# #1#centre                                                    254
# #1#subCentre                                                   0
# #1#softwareVersionNumber                                MPEF_2.9
# #1#databaseIdentification                                   None
# #1#satelliteIdentifier                                        56
# #1#satelliteChannelCentreFrequency             399723300000000.0
# #1#directionOfMotionOfMovingObservingPlatform               None
# #1#crossTrackResolution                                     None
# #1#alongTrackResolution                                     None
# #1#segmentSizeAtNadirInXDirection                          32000
# #1#segmentSizeAtNadirInYDirection                          32000
# #1#windProcessingMethod                                     None
# #1#tracerCorrelationMethod                                     2
# #1#satelliteDerivedWindComputationMethod                       2
# #1#landOrSeaQualifier                                          1
# #1#dayOrNightQualifier                                      None
# #1#gridPointIdentifier                                      None
# #1#latitude                                            -23.51801
# #1#longitude                                            88.89647
# #1#year                                                     2024
# #1#month                                                       2
# #1#day                                                        14
# #1#hour                                                        0
# #1#minute                                                     30
# #1#second                                                      0
# #1#timePeriod                                               3600
# #1#extendedHeightAssignmentMethod                              4
# #1#pressure                                              94140.0
# #1#windDirection                                             126
# #1#windSpeed                                                 4.0
# #1#u                                                        -3.3
# #1#v                                                         2.4
# #1#airTemperature                                          292.3
# #1#heightOfTopOfCloud                                       None
# #1#satelliteZenithAngle                                    57.37
# #1#observationSequenceNumber                                None
# #2#extendedHeightAssignmentMethod                              1
# #2#pressure                                              80690.0
# #2#airTemperature                                          288.0
# #2#heightOfTopOfCloud                                       None
#
#                                                            31344  \
# #1#centre                                                    254
# #1#subCentre                                                   0
# #1#softwareVersionNumber                                MPEF_2.9
# #1#databaseIdentification                                   None
# #1#satelliteIdentifier                                        56
# #1#satelliteChannelCentreFrequency             399723300000000.0
# #1#directionOfMotionOfMovingObservingPlatform               None
# #1#crossTrackResolution                                     None
# #1#alongTrackResolution                                     None
# #1#segmentSizeAtNadirInXDirection                          32000
# #1#segmentSizeAtNadirInYDirection                          32000
# #1#windProcessingMethod                                     None
# #1#tracerCorrelationMethod                                     2
# #1#satelliteDerivedWindComputationMethod                       2
# #1#landOrSeaQualifier                                          1
# #1#dayOrNightQualifier                                      None
# #1#gridPointIdentifier                                      None
# #1#latitude                                            -23.51971
# #1#longitude                                            87.54318
# #1#year                                                     2024
# #1#month                                                       2
# #1#day                                                        14
# #1#hour                                                        0
# #1#minute                                                     30
# #1#second                                                      0
# #1#timePeriod                                               3600
# #1#extendedHeightAssignmentMethod                              4
# #1#pressure                                              92170.0
# #1#windDirection                                             123
# #1#windSpeed                                                 3.7
# #1#u                                                        -3.1
# #1#v                                                         2.0
# #1#airTemperature                                          291.6
# #1#heightOfTopOfCloud                                       None
# #1#satelliteZenithAngle                                    56.17
# #1#observationSequenceNumber                                None
# #2#extendedHeightAssignmentMethod                              1
# #2#pressure                                              80720.0
# #2#airTemperature                                          287.4
# #2#heightOfTopOfCloud                                       None
#
#                                                            31345  \
# #1#centre                                                    254
# #1#subCentre                                                   0
# #1#softwareVersionNumber                                MPEF_2.9
# #1#databaseIdentification                                   None
# #1#satelliteIdentifier                                        56
# #1#satelliteChannelCentreFrequency             399723300000000.0
# #1#directionOfMotionOfMovingObservingPlatform               None
# #1#crossTrackResolution                                     None
# #1#alongTrackResolution                                     None
# #1#segmentSizeAtNadirInXDirection                          32000
# #1#segmentSizeAtNadirInYDirection                          32000
# #1#windProcessingMethod                                     None
# #1#tracerCorrelationMethod                                     2
# #1#satelliteDerivedWindComputationMethod                       2
# #1#landOrSeaQualifier                                          1
# #1#dayOrNightQualifier                                      None
# #1#gridPointIdentifier                                      None
# #1#latitude                                            -23.47714
# #1#longitude                                            87.12715
# #1#year                                                     2024
# #1#month                                                       2
# #1#day                                                        14
# #1#hour                                                        0
# #1#minute                                                     30
# #1#second                                                      0
# #1#timePeriod                                               3600
# #1#extendedHeightAssignmentMethod                              4
# #1#pressure                                              86740.0
# #1#windDirection                                             114
# #1#windSpeed                                                 3.9
# #1#u                                                        -3.5
# #1#v                                                         1.6
# #1#airTemperature                                          289.0
# #1#heightOfTopOfCloud                                       None
# #1#satelliteZenithAngle                                    55.78
# #1#observationSequenceNumber                                None
# #2#extendedHeightAssignmentMethod                              1
# #2#pressure                                              77420.0
# #2#airTemperature                                          285.6
# #2#heightOfTopOfCloud                                       None
#
#                                                            31346
# #1#centre                                                    254
# #1#subCentre                                                   0
# #1#softwareVersionNumber                                MPEF_2.9
# #1#databaseIdentification                                   None
# #1#satelliteIdentifier                                        56
# #1#satelliteChannelCentreFrequency             399723300000000.0
# #1#directionOfMotionOfMovingObservingPlatform               None
# #1#crossTrackResolution                                     None
# #1#alongTrackResolution                                     None
# #1#segmentSizeAtNadirInXDirection                          32000
# #1#segmentSizeAtNadirInYDirection                          32000
# #1#windProcessingMethod                                     None
# #1#tracerCorrelationMethod                                     2
# #1#satelliteDerivedWindComputationMethod                       2
# #1#landOrSeaQualifier                                          1
# #1#dayOrNightQualifier                                      None
# #1#gridPointIdentifier                                      None
# #1#latitude                                             -23.4157
# #1#longitude                                             84.9351
# #1#year                                                     2024
# #1#month                                                       2
# #1#day                                                        14
# #1#hour                                                        0
# #1#minute                                                     30
# #1#second                                                      0
# #1#timePeriod                                               3600
# #1#extendedHeightAssignmentMethod                              4
# #1#pressure                                              77290.0
# #1#windDirection                                             118
# #1#windSpeed                                                 3.9
# #1#u                                                        -3.5
# #1#v                                                         1.8
# #1#airTemperature                                          284.9
# #1#heightOfTopOfCloud                                       None
# #1#satelliteZenithAngle                                    53.83
# #1#observationSequenceNumber                                None
# #2#extendedHeightAssignmentMethod                              1
# #2#pressure                                              68710.0
# #2#airTemperature                                          278.5
# #2#heightOfTopOfCloud                                       None
#
# [40 rows x 31347 columns]

# %%
# UPPER OR LOWER LEVEL WIND
# Note :: uncomment pressure brackets --- GOTO [@UPPER_LEVEL] OR [@LOWER_LEVEL]
import pdbufr
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.cm import ScalarMappable
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.colors import Normalize, ListedColormap

latBound = [7.22, 37.454]
lngBound = [43.753, 102.363]

## [@UPPER_LEVEL]
minMaxVal = [10000 , 50000]
pressure_brackets = [
    (10000, 25000),
    (25100, 35000),
    (35100, 50000)
]

## [@LOWER_LEVEL]
# minMaxVal = [40000 , 95000]
# pressure_brackets = [
#     (40000, 59900),
#     (60000, 79900),
#     (80000, 95000)
# ]

filtered_df = df[
    (df['#1#latitude'] >= latBound[0])
    & (df['#1#latitude'] <= latBound[1])
    & (df['#1#longitude'] >= lngBound[0])
    & (df['#1#longitude'] <= lngBound[1])
    & (df['#1#pressure'] >= minMaxVal[0])
    & (df['#1#pressure'] <= minMaxVal[1])
]

pressure_labels = ['blue', 'green', 'red']

filtered_df['#1#pressureColor'] = np.select(
    [((filtered_df['#1#pressure'] >= low) & (filtered_df['#1#pressure'] <= high)) for low, high in pressure_brackets],
    pressure_labels, default='black'
)

# Correct the wind vector calculation
# windu = -df['#1#windSpeed'] * np.sin(np.radians(df['#1#windDirection']))
# windv = -df['#1#windSpeed'] * np.cos(np.radians(df['#1#windDirection']))

# Create a cartopy map with PlateCarree projection
# print(filtered_df['#1#windSpeed'])
fig = plt.figure(figsize=(16, 16))
ax = plt.axes(projection=ccrs.Mercator())

# cmap = ListedColormap(pressure_labels)
# norm = plt.Normalize(minMaxVal[0], minMaxVal[1])
# sm = ScalarMappable(cmap=cmap, norm=norm)
# sm.set_array([])
# cbar = plt.colorbar(sm, ax=ax, label='Pressure')


# Plot wind barbs with different colors based on pressure brackets
barbs = ax.barbs(filtered_df['#1#longitude'], filtered_df['#1#latitude'], filtered_df['#1#u'] ,filtered_df['#1#v'], color=filtered_df['#1#pressureColor'], pivot='middle', transform=ccrs.PlateCarree())
# Add coastlines and other features to the map
# ax.coastlines()
# ax.add_feature(cfeature.BORDERS, linestyle=':')
# ax.add_feature(cfeature.LAND, edgecolor='black', facecolor='lightgray')

plt.show()
# Out:
# <ipython-input-5-c71e76c68257>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['#1#pressureColor'] = np.select(

# %%
import altair as alt
chart = alt.Chart(df).mark_point().encode(
    longitude='longitude:Q',
    latitude='latitude:Q',
    color='windDirection:Q',
    tooltip=['#1#latitude', '#1#longitude', '#1#windDirection', '#1#windSpeed', '#1#airTemperature']
).properties(width=600,height=400)
# chart.save('chart.html')
chart
# Out:
# alt.Chart(...)

# %%
# ========= TEMP CODE ====================

# %%
# !pip install cfgrib matplotlib numpy

# %%
# !pip install pybufr-ecmwf
